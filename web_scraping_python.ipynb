# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/danielcanueto/misc/blob/master/web_scraping_python.ipynb)

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Thu Sep  6 11:17:11 2018
@author: kerry
"""
# Out:
# '\nCreated on Thu Sep  6 11:17:11 2018\n@author: kerry\n'

# %%
# import libraries
import urllib.request
from bs4 import BeautifulSoup
import csv

# %%
# specify the url
urlpage =  'http://www.fasttrack.co.uk/league-tables/tech-track-100/league-table/' 
print(urlpage)
# query the website and return the html to the variable 'page'
page = urllib.request.urlopen(urlpage)
# parse the html using beautiful soup and store in variable 'soup'
soup = BeautifulSoup(page, 'html.parser')
# find results within table
table = soup.find('table', attrs={'class': 'tableSorter'})
results = table.find_all('tr')
print('Number of results', len(results))

# create and write headers to a list 
rows = []
rows.append(['Rank', 'Company Name', 'Webpage', 'Description', 'Location', 'Year end', 'Annual sales rise over 3 years', 'Sales £000s', 'Staff', 'Comments'])

# loop over results
for result in results:
    # find all columns per result
    data = result.find_all('td')
    # check that columns have data 
    if len(data) == 0: 
        continue
    
    # write columns to variables
    rank = data[0].getText()
    company = data[1].getText()
    location = data[2].getText()
    yearend = data[3].getText()
    salesrise = data[4].getText()
    sales = data[5].getText()
    staff = data[6].getText()
    comments = data[7].getText()
    
    # print('Company is', company)
    # Company is WonderblyPersonalised children's books
    # print('Sales', sales)
    # Sales *25,860

    # extract description from the name
    companyname = data[1].find('span', attrs={'class':'company-name'}).getText()    
    description = company.replace(companyname, '')
    
    # remove unwanted characters
    sales = sales.strip('*').strip('†').replace(',','')
    
    # go to link and extract company website
    url = data[1].find('a').get('href')
    page = urllib.request.urlopen(url)
    # parse the html using beautiful soup and store in variable 'soup'
    soup = BeautifulSoup(page, 'html.parser')
    # find the last result in the table and get the link
    try:
        tableRow = soup.find('table').find_all('tr')[-1]
        webpage = tableRow.find('a').get('href')
    except:
        webpage = None
    
    # write each result to rows
    rows.append([rank, companyname, webpage, description, location, yearend, salesrise, sales, staff, comments])


print(rows)


## Create csv and write rows to output file
with open('techtrack100.csv','w', newline='') as f_output:
    csv_output = csv.writer(f_output)
    csv_output.writerows(rows)
# Out:
# http://www.fasttrack.co.uk/league-tables/tech-track-100/league-table/
# Number of results 101
# [['Rank', 'Company Name', 'Webpage', 'Description', 'Location', 'Year end', 'Annual sales rise over 3 years', 'Sales £000s', 'Staff', 'Comments'], ['1', 'Wonderbly', 'http://www.wonderbly.com', "Personalised children's books", 'East London', 'Apr-17', '294.27%', '25860', '80', 'Has sold nearly 3m customisable children’s books in 200 countries'], ['2', 'Smarkets', 'http://www.smarkets.com', 'Betting exchange', 'Central London', 'Dec-16', '280.05%', '25417', '78', 'Says its staff set their own salaries and have an unlimited holiday allowance'], ['3', 'Darktrace', 'http://www.darktrace.com', 'Cyber-security developer', 'Cambridge', 'Jun-17', '267.61%', '31000', '475', 'Has raised more than $180m from investors including Invoke Capital'], ['4', 'Hunter Macdonald', 'http://www.huntermacdonald.co.uk', 'IT consultancy', 'Reading', 'Jun-17', '267.06%', '29147', '437', 'Employs a team of more than 100 developers to create bespoke applications'], ['5', 'TransferWise', 'http://www.transferwise.com', 'Currency transfer provider', 'East London', 'Mar-17', '226.85%', '67010', '598', 'Valued at above $1bn after raising $117m from backers including Sir Richard Branson'], ['6', 'Festicket', 'http://www.festicket.com', 'Festival booking services', 'Central London', 'Dec-16', '224.83%', '16026', '51', 'Has created a one-stop-shop for 2.5m festival-goers'], ['7', 'Oakbrook', 'http://www.oakbrookfinance.com', 'Consumer finance provider', 'Nottingham', 'Dec-16', '213.84%', '24848', '70', "Uses machine learning to help estimate borrowers' credit risk"], ['8', 'SuperAwesome', 'http://www.superawesome.tv', "Children's advertising services", 'Central London', 'Dec-16', '210.71%', '10181', '80', "Serves some of the world's largest kids' brands from offices in America, Asia and Australia"], ['9', 'LADbible Group', 'http://www.theladbible.com', 'Online entertainment community', 'Manchester', 'Dec-16', '208.17%', '9221', '110', 'Claims its flagship channels are followed by half of all 18-30 year olds in the UK'], ['10', 'Receipt Bank', 'http://www.receipt-bank.com', 'Bookkeeping automation services', 'Central London', 'Dec-16', '185.30%', '6177', '185', 'Says 100,000 businesses in America, Europe and Australia use its bookkeeping software'], ['11', 'GoCardless', 'http://www.gocardless.com', 'Payment services provider', 'Central London', 'Dec-16', '174.15%', '5969', '120', 'Processes £3bn of direct debit payments a year for more than 25,000 businesses'], ['12', 'Brainlabs', 'http://www.brainlabsdigital.com', 'Digital marketing agency', 'Central London', 'Mar-17', '172.11%', '14753', '105', 'Founder Dan Gilbert left Google to start this company in his parents’ attic in 2011'], ['13', 'Outplay Entertainment', 'http://www.outplay.com', 'Mobile games developer', 'Dundee', 'Dec-16', '171.61%', '15585', '210', 'More than 20m players have downloaded its Alien Creeps game'], ['14', 'Infinox', 'http://www.infinox.com', 'Currency trading platform', 'Central London', 'Mar-17', '164.26%', '17542', '18', 'Generates two-thirds of its sales from traders in Asia'], ['15', 'Virtus Data Centres', 'http://www.virtusdatacentres.com', 'Data centre operator', 'Central London', 'Dec-16', '163.48%', '23573', '45', 'Owns and operates data centres in Enfield, Hayes and Slough'], ['16', 'Optal', 'http://www.optal.com', 'Payment services provider', 'Central London', 'Dec-16', '162.84%', '129061', '38', 'Offers payment processing in 34 currencies'], ['17', 'Hyperoptic', 'http://www.hyperoptic.com', 'Internet services provider', 'West London', 'Dec-16', '160.86%', '8775', '297', 'Aims to provide superfast broadband to more than 2m homes by 2022'], ['18', 'WDX', 'http://www.wealth-dynamix.com', 'Wealth management platform', 'Central London', 'Sep-16', '155.25%', '6172', '40', 'Its software is used by 10 of the UK’s top 25 wealth management firms'], ['19', 'Perkbox', 'http://www.perkbox.com', 'Employee engagement services', 'Central London', 'Dec-16', '146.34%', '14675', '96', 'Companies  ...

# %%
rows
# Out:
# [['Rank',
#   'Company Name',
#   'Webpage',
#   'Description',
#   'Location',
#   'Year end',
#   'Annual sales rise over 3 years',
#   'Sales £000s',
#   'Staff',
#   'Comments'],
#  ['1',
#   'Wonderbly',
#   'http://www.wonderbly.com',
#   "Personalised children's books",
#   'East London',
#   'Apr-17',
#   '294.27%',
#   '25860',
#   '80',
#   'Has sold nearly 3m customisable children’s books in 200 countries'],
#  ['2',
#   'Smarkets',
#   'http://www.smarkets.com',
#   'Betting exchange',
#   'Central London',
#   'Dec-16',
#   '280.05%',
#   '25417',
#   '78',
#   'Says its staff set their own salaries and have an unlimited holiday allowance'],
#  ['3',
#   'Darktrace',
#   'http://www.darktrace.com',
#   'Cyber-security developer',
#   'Cambridge',
#   'Jun-17',
#   '267.61%',
#   '31000',
#   '475',
#   'Has raised more than $180m from investors including Invoke Capital'],
#  ['4',
#   'Hunter Macdonald',
#   'http://www.huntermacdonald.co.uk',
#   'IT consultancy',
#   'Reading',
#   'Jun-17',
#   '267.06%',
#   '29147',
#   '437',
#   'Employs a team of more than 100 developers to create bespoke applications'],
#  ['5',
#   'TransferWise',
#   'http://www.transferwise.com',
#   'Currency transfer provider',
#   'East London',
#   'Mar-17',
#   '226.85%',
#   '67010',
#   '598',
#   'Valued at above $1bn after raising $117m from backers including Sir Richard Branson'],
#  ['6',
#   'Festicket',
#   'http://www.festicket.com',
#   'Festival booking services',
#   'Central London',
#   'Dec-16',
#   '224.83%',
#   '16026',
#   '51',
#   'Has created a one-stop-shop for 2.5m festival-goers'],
#  ['7',
#   'Oakbrook',
#   'http://www.oakbrookfinance.com',
#   'Consumer finance provider',
#   'Nottingham',
#   'Dec-16',
#   '213.84%',
#   '24848',
#   '70',
#   "Uses machine learning to help estimate borrowers' credit risk"],
#  ['8',
#   'SuperAwesome',
#   'http://www.superawesome.tv',
#   "Children's advertising services",
#   'Central London',
#   'Dec-16',
#   '210.71%',
#   '10181',
#   '80',
#   "Serves some of the world's largest kids' brands from offices in America, Asia and Australia"],
#  ['9',
#   'LADbible Group',
#   'http://www.theladbible.com',
#   'Online entertainment community',
#   'Manchester',
#   'Dec-16',
#   '208.17%',
#   '9221',
#   '110',
#   'Claims its flagship channels are followed by half of all 18-30 year olds in the UK'],
#  ['10',
#   'Receipt Bank',
#   'http://www.receipt-bank.com',
#   'Bookkeeping automation services',
#   'Central London',
#   'Dec-16',
#   '185.30%',
#   '6177',
#   '185',
#   'Says 100,000 businesses in America, Europe and Australia use its bookkeeping software'],
#  ['11',
#   'GoCardless',
#   'http://www.gocardless.com',
#   'Payment services provider',
#   'Central London',
#   'Dec-16',
#   '174.15%',
#   '5969',
#   '120',
#   'Processes £3bn of direct debit payments a year for more than 25,000 businesses'],
#  ['12',
#   'Brainlabs',
#   'http://www.brainlabsdigital.com',
#   'Digital marketing agency',
#   'Central London',
#   'Mar-17',
#   '172.11%',
#   '14753',
#   '105',
#   'Founder Dan Gilbert left Google to start this company in his parents’ attic in 2011'],
#  ['13',
#   'Outplay Entertainment',
#   'http://www.outplay.com',
#   'Mobile games developer',
#   'Dundee',
#   'Dec-16',
#   '171.61%',
#   '15585',
#   '210',
#   'More than 20m players have downloaded its Alien Creeps game'],
#  ['14',
#   'Infinox',
#   'http://www.infinox.com',
#   'Currency trading platform',
#   'Central London',
#   'Mar-17',
#   '164.26%',
#   '17542',
#   '18',
#   'Generates two-thirds of its sales from traders in Asia'],
#  ['15',
#   'Virtus Data Centres',
#   'http://www.virtusdatacentres.com',
#   'Data centre operator',
#   'Central London',
#   'Dec-16',
#   '163.48%',
#   '23573',
#   '45',
#   'Owns and operates data centres in Enfield, Hayes and Slough'],
#  ['16',
#   'Optal',
#   'http://www.optal.com',
#   'Payment services provider',
#   'Central London',
#   'Dec-16',
#   '162.84%',
#   '129061',
#   '38',
#   'Offers payment processing in 34 currencies'],
#  ['17',
#   'Hyperoptic',
#   'http://www.hyperoptic.com',
#   'Internet services provider',
#   'West London',
#   'Dec-16',
#   '160.86%',
#   '8775',
#   '297',
#   'Aims to provide superfast broadband to more than 2m homes by 2022'],
#  ['18',
#   'WDX',
#   'http://www.wealth-dynamix.com',
#   'Wealth management platform',
#   'Central London',
#   'Sep-16',
#   '155.25%',
#   '6172',
#   '40',
#   'Its software is used by 10 of the UK’s top 25 wealth management firms'],
#  ['19',
#   'Perkbox',
#   'http://www.perkbox.com',
#   'Employee engagement services',
#   'Central London',
#   'Dec-16',
#   '146.34%',
#   '14675',
#   '96',
#   'Companies use its platform to offer staff perks such as two-for-one meals'],
#  ['20',
#   'LoopMe',
#   'http://www.loopme.com',
#   'Advertising technology developer',
#   'Central London',
#   'Dec-16',
#   '143.74%',
#   '12820',
#   '60',
#   'Says its artificial-intelligence technology reaches 2bn devices around the world'],
#  ['21',
#   'iwoca',
#   'http://www.iwoca.co.uk',
#   'Business finance provider',
#   'Central London',
#   'Dec-16',
#   '128.53%',
#   '13236',
#   '140',
#   'Its 140 employees include three former Olympians'],
#  ['22',
#   'UKCloud',
#   'http://www.ukcloud.com',
#   'Cloud services provider',
#   'Farnborough',
#   'Mar-17',
#   '127.13%',
#   '42918',
#   '158',
#   "High-profile investors include Tim Henman, Andy Murray and Pink Floyd's Nick Mason"],
#  ['23',
#   'Yieldify',
#   'http://www.yieldify.com',
#   'Marketing technology developer',
#   'Central London',
#   'Apr-17',
#   '124.97%',
#   '9106',
#   '103',
#   'Has raised nearly £15m from investors including Google Ventures and Softbank'],
#  ['24',
#   'LoveCrafts',
#   'http://www.lovecrafts.com',
#   'Crafts communities platform',
#   'Central London',
#   'Mar-17',
#   '124.62%',
#   '18132',
#   '100',
#   'With £44m of venture capital, it has created a crafts community covering 140 countries'],
#  ['25',
#   'PsiOxus',
#   'http://www.psioxus.com',
#   'Biotechnology developer',
#   'Abingdon',
#   'Nov-16',
#   '120.50%',
#   '8564',
#   '46',
#   'Its new solid tumour-destroying virus is entering clinical trials in America'],
#  ['26',
#   'ZappiStore',
#   'http://www.zappistore.com',
#   'Research services provider',
#   'Central London',
#   'Dec-16',
#   '116.87%',
#   '10975',
#   '146',
#   'Holds weekly hackathons with its clients and programmers'],
#  ['27',
#   'Funding Circle',
#   'http://www.fundingcircle.com',
#   'Peer-to-peer lending platform',
#   'Central London',
#   'Dec-16',
#   '111.80%',
#   '50878',
#   '741',
#   'Reports that more than £3bn has been lent through its website to 33,000 businesses'],
#  ['28',
#   'ImpulsePay',
#   'http://www.impulsepay.com',
#   'Mobile payment technology',
#   'Central London',
#   'Dec-16',
#   '109.50%',
#   '16242',
#   '7',
#   'CrossCountry Trains uses its technology to charge customers for wi-fi access'],
#  ['29',
#   'Neuven',
#   'http://www.neuven.co.uk',
#   'HR software developer',
#   'Manchester',
#   'Jul-16',
#   '107.11%',
#   '86354',
#   '24',
#   'Its technology is used by employers of temporary staff'],
#  ['30',
#   'Love Energy Savings',
#   'http://www.loveenergysavings.com',
#   'Price comparison website',
#   'Bolton',
#   'Dec-16',
#   '103.17%',
#   '13207',
#   '114',
#   'Says it has helped 130,000 UK homes and businesses save on energy costs since 2007'],
#  ['31',
#   'Red Badger',
#   'http://www.red-badger.com',
#   'Digital consultancy',
#   'East London',
#   'Oct-16',
#   '102.61%',
#   '7015',
#   '75',
#   'Designed and built a new content management system for Sky'],
#  ['32',
#   'Threads Styling',
#   'http://www.threadsstyling.com',
#   'Online fashion services',
#   'East London',
#   'Dec-16',
#   '102.30%',
#   '8291',
#   '44',
#   'Uses social media to make it easier for fashionistas to buy luxury clothes'],
#  ['33',
#   'Victor',
#   'http://www.flyvictor.com',
#   'Online private jet hire',
#   'Central London',
#   'Dec-16',
#   '101.33%',
#   '29592',
#   '59',
#   'Counts Sir Elton John among its investors'],
#  ['34',
#   'Immunocore',
#   'http://www.immunocore.com',
#   'Biotechnology developer',
#   'Abingdon',
#   'Dec-16',
#   '100.41%',
#   '16465',
#   '279',
#   'Has raised £205m from investors including Woodford Investment Management and Malin'],
#  ['35',
#   'Blis',
#   'http://www.blis.com',
#   'Advertising technology provider',
#   'Central London',
#   'Dec-16',
#   '100.15%',
#   '28151',
#   '138',
#   'Its location-predicting tool is used by Stella Artois to target new customers in bars'],
#  ['36',
#   'StarLeaf',
#   'http://www.starleaf.com',
#   'Video conferencing provider',
#   'Watford',
#   'Dec-16',
#   '99.11%',
#   '6048',
#   '130',
#   'Its founders set up Tech Track 100 alumnus Codian and sold it for $270m in 2007'],
#  ['37',
#   'LendInvest',
#   'http://www.lendinvest.com',
#   'Property finance provider',
#   'Central London',
#   'Mar-17',
#   '97.90%',
#   '22111',
#   '102',
#   'It has taken a 10% share of the short-term mortgage market'],
#  ['38',
#   'Captify',
#   'http://www.captify.co.uk',
#   'Advertising technology company',
#   'Central London',
#   'Mar-17',
#   '96.05%',
#   '25054',
#   '181',
#   'Analysis of 33bn searches a month provides data for its campaign and marketing insights'],
#  ['39',
#   'PM Connect',
#   'http://www.pmconnect.co.uk',
#   'Mobile content provider',
#   'Birmingham',
#   'Feb-17',
#   '95.54%',
#   '14470',
#   '25',
#   'Bounce Games, iFitness and Love Food are among this company’s brands'],
#  ['40',
#   'WorldRemit',
#   'http://www.worldremit.com',
#   'Currency transfer provider',
#   'Central London',
#   'Dec-16',
#   '95.07%',
#   '41054',
#   '324',
#   'Founder came up with the idea for the business after paying huge fees on money transfers'],
#  ['41',
#   'BBOXX',
#   'http://www.bboxx.co.uk',
#   'Solar system manufacturer',
#   'West London',
#   'Dec-16',
#   '94.77%',
#   '8898',
#   '447',
#   'Aims to provide electricity for 20m people in developing countries by 2020'],
#  ['42',
#   'Double Eleven',
#   'http://www.double11.com',
#   'Video games publisher',
#   'Middlesbrough',
#   'Sep-16',
#   '92.32%',
#   '6112',
#   '38',
#   'Says its games have been played by more than 10m people worldwide'],
#  ['43',
#   'Symetrica',
#   'http://www.symetrica.com',
#   'Radiation detection equipment',
#   'Southampton',
#   'Sep-16',
#   '91.72%',
#   '8175',
#   '50',
#   'Its technology can detect materials that may be used in dirty bombs'],
#  ['44',
#   'MiQ',
#   'http://www.mediaiqdigital.com',
#   'Digital marketing agency',
#   'Central London',
#   'Dec-16',
#   '91.20%',
#   '91880',
#   '330',
#   'Develops its own analytical software in Bangalore, India'],
#  ['45',
#   'Kano',
#   'http://www.kano.me',
#   'Educational computer developer',
#   'East London',
#   'Dec-16',
#   '87.88%',
#   '6295',
#   '44',
#   'Has shipped more than 150,000 of its build-your-own computer kits to 86 countries'],
#  ['46',
#   'Black Swan Data',
#   'http://www.blackswan.com',
#   'Analytical software developer',
#   'Central London',
#   'May-17',
#   '87.22%',
#   '15098',
#   '252',
#   'Last year it raised £6.2m to develop its product platform and accelerate international growth'],
#  ['47',
#   'Adaptive',
#   'http://www.weareadaptive.com',
#   'Financial software developer',
#   'Central London',
#   'Jun-17',
#   '86.24%',
#   '15198',
#   '116',
#   'Increased staff from five to more than 100 in just five years'],
#  ['48',
#   'Capital on Tap',
#   'http://www.capitalontap.com',
#   'Business finance provider',
#   'West London',
#   'Mar-17',
#   '84.49%',
#   '9080',
#   '54',
#   'Its founders also set up Paymentsense, No 63 in the league table'],
#  ['49',
#   'Zopa',
#   'http://www.zopa.com',
#   'Peer-to-peer lending platform',
#   'South London',
#   'Dec-16',
#   '83.49%',
#   '33220',
#   '188',
#   'Says it was the first European peer-to-peer lender to exceed £2bn in loans'],
#  ['50',
#   'Cloud Technology Solutions',
#   'http://www.cloudsolutions.co.uk',
#   'Cloud software developer',
#   'Manchester',
#   'Mar-17',
#   '82.62%',
#   '15177',
#   '67',
#   'Its CloudMigrator software tool has moved 6.2m users to the cloud'],
#  ['51',
#   'Ebury',
#   'http://www.eburypartners.com',
#   'Business finance provider',
#   'Central London',
#   'Apr-17',
#   '82.12%',
#   '38052',
#   '480',
#   'Has raised more than £85m from venture capital and private equity investors'],
#  ['52',
#   'Farfetch',
#   'http://www.farfetch.com',
#   'Online fashion platform',
#   'East London',
#   'Dec-16',
#   '81.90%',
#   'n/a',
#   '1,242',
#   'Secured a $397m investment from Chinese ecommerce business JD.com in June'],
#  ['53',
#   'Epos Now',
#   'http://www.eposnow.com',
#   'Payment systems developer',
#   'Norwich',
#   'May-17',
#   '81.21%',
#   '13947',
#   '293',
#   'More than 30,000 businesses use its cloud-based point-of-sale systems'],
#  ['54',
#   'Performance Horizon',
#   'http://www.performancehorizon.com',
#   'Marketing software developer',
#   'Newcastle',
#   'Dec-16',
#   '77.61%',
#   '11895',
#   '124',
#   'Its founders set up Tech Track 100 alumnus Buy.at and sold it to AOL for $125m in 2008'],
#  ['55',
#   'Qualasept Pharmaxo',
#   'http://www.bathasu.com',
#   'Pharmaceuticals manufacturer',
#   'Wiltshire',
#   'Apr-16',
#   '76.95%',
#   '87857',
#   '141',
#   "Claims it has developed the UK's single biggest aseptic clean room"],
#  ['56',
#   'iPulse',
#   'http://www.cyden.com',
#   'Hair removal technology',
#   'Swansea',
#   'Dec-16',
#   '72.47%',
#   '17492',
#   '32',
#   'Uses pulsed light technology to permanently remove unwanted body hair'],
#  ['57',
#   'Clyde Space',
#   'http://www.clyde.space',
#   'Satellite manufacturer',
#   'Glasgow',
#   'Apr-16',
#   '71.95%',
#   '5257',
#   '75',
#   'Builds up to 12 flight-ready mini-satellites each month'],
#  ['58',
#   'CashFlows',
#   'http://www.cashflows.com',
#   'Payment services provider',
#   'Cambridge',
#   'Dec-16',
#   '71.91%',
#   '37312',
#   '78',
#   'Acquired online payment provider iCheque last year'],
#  ['59',
#   'CitNOW',
#   'http://www.citnow.com',
#   'Video software developer',
#   'Wokingham',
#   'Dec-16',
#   '71.89%',
#   '7019',
#   '67',
#   'Has subscribers in 44 countries, who produce 500 hours of video every day'],
#  ['60',
#   'geo',
#   'http://www.geotogether.com',
#   'Smart energy monitoring',
#   'Cambridge',
#   'Mar-17',
#   '71.76%',
#   '22603',
#   '56',
#   'Has sold more than 4m devices to help people monitor energy usage in their homes'],
#  ['61',
#   'Trak Global Group',
#   'http://www.trakglobal.co.uk',
#   'Vehicle tracking technology',
#   'Crewe',
#   'Jun-17',
#   '70.60%',
#   '25296',
#   '225',
#   'Says its software allows firms such as Rentokil to track their vehicles via employees’ phones'],
#  ['62',
#   'RateSetter',
#   'http://www.ratesetter.com',
#   'Peer-to-peer lending platform',
#   'East London',
#   'Mar-17',
#   '68.00%',
#   '23701',
#   '187',
#   '350,000 individuals and small firms have used its platform to borrow a total of £2bn'],
#  ['63',
#   'Paymentsense',
#   'http://www.paymentsense.co.uk',
#   'Payment services provider',
#   'West London',
#   'Mar-17',
#   '67.54%',
#   '62301',
#   '235',
#   'Serves 57,000 small businesses and processed £5.5bn of card payments last year'],
#  ['64',
#   'Grapeshot',
#   'http://www.grapeshot.com',
#   'Advertising technology developer',
#   'Cambridge',
#   'Dec-16',
#   '65.68%',
#   '9045',
#   '76',
#   'Its founders spent four years developing its technology before launching'],
#  ['65',
#   'AnalogFolk',
#   'http://www.analogfolk.com',
#   'Digital marketing agency',
#   'Central London',
#   'Dec-16',
#   '64.50%',
#   '27662',
#   '220',
#   "Created the first UK brand campaign to use Snapchat's wearable glasses, for Costa Coffee"],
#  ['66',
#   'Egress',
#   'http://www.egress.com',
#   'Data security provider',
#   'Central London',
#   'Dec-16',
#   '62.09%',
#   '5442',
#   '100',
#   "Users of its platform can revoke access to emails after they have reached the recipient's inbox"],
#  ['67',
#   'TouchNote',
#   'http://www.touchnote.com',
#   'Personalised photo-card provider',
#   'Central London',
#   'Dec-16',
#   '62.07%',
#   '5072',
#   '16',
#   'Has sent more than 9m personalised photo cards to 200 countries'],
#  ['68',
#   'Secret Escapes',
#   'http://www.secretescapes.com',
#   'Online travel services',
#   'Central London',
#   'Dec-16',
#   '61.31%',
#   '48674',
#   '368',
#   'Has raised £51m from investors including Google Ventures'],
#  ['69',
#   'Giacom',
#   'http://www.giacom.com',
#   'Cloud services provider',
#   'Hull',
#   'Jul-16',
#   '60.73%',
#   '6629',
#   '50',
#   'Its MessageStream platform is used by more than 4,000 software resellers'],
#  ['70',
#   'LPW Technology',
#   'http://www.lpwtechnology.com',
#   'Metal powder manufacturer',
#   'Cheshire',
#   'Aug-16',
#   '60.69%',
#   '10406',
#   '82',
#   'Investing £20m over two years to develop its manufacturing facilities and product range'],
#  ['71',
#   'Prepaid Financial Services',
#   'http://www.prepaidfinancialservices.com',
#   'Payment services provider',
#   'Central London',
#   'Dec-16',
#   '59.05%',
#   '41843',
#   '48',
#   'Its prepaid cards are used by governments, multinational companies and individuals'],
#  ['72',
#   'Croud',
#   'http://www.croud.co.uk',
#   'Digital marketing agency',
#   'East London',
#   'Mar-17',
#   '58.75%',
#   '7714',
#   '83',
#   'Employs more than 1,200 digital marketing experts, or ‘Croudies’, around the world'],
#  ['73',
#   'Milk Visual Effects',
#   'http://www.milk-vfx.com',
#   'Visual effects developer',
#   'Central London',
#   'Mar-17',
#   '57.94%',
#   '10273',
#   '109',
#   'Co-founder Sara Bennett won an Oscar for creating visual effects used in the film Ex Machina'],
#  ['74',
#   'The Media Image',
#   'http://www.the-media-image.com',
#   'Digital marketing agency',
#   'South London',
#   'Feb-17',
#   '56.77%',
#   '18398',
#   '33',
#   "Founded by the man who was the first recruit for Google UK's Adwords"],
#  ['75',
#   'Ipsotek',
#   'http://www.ipsotek.com',
#   'Video analytics provider',
#   'West London',
#   'Dec-16',
#   '55.92%',
#   '5062',
#   '41',
#   'Its patented software analyses CCTV footage to identify security threats'],
#  ['76',
#   'Bede Gaming',
#   'http://www.bedegaming.com',
#   'Gambling software developer',
#   'Newcastle',
#   'Dec-16',
#   '54.41%',
#   '8157',
#   '120',
#   'Employs 120 developers at its offices in Newcastle, London and Sofia, Bulgaria'],
#  ['77',
#   'Mediatonic',
#   'http://www.mediatonicgames.com',
#   'Computer games developer',
#   'Central London',
#   'Sep-16',
#   '53.77%',
#   '7367',
#   '110',
#   'Worked with Warner Bros to create a mobile game for Harry Potter prequel Fantastic Beasts'],
#  ['78',
#   'InfoMedia',
#   'http://www.infomedia-services.co.uk',
#   'Mobile payment provider',
#   'Northampton',
#   'Oct-16',
#   '52.34%',
#   '34020',
#   '30',
#   "Last year it processed 40m payments for customers' mobile phone bills"],
#  ['79',
#   'M Squared',
#   'http://www.m2lasers.com',
#   'Laser designer and manufacturer',
#   'Glasgow',
#   'Feb-16',
#   '52.13%',
#   '13896',
#   '90',
#   'Its advanced laser systems are used by Nobel prize-winning scientists'],
#  ['80',
#   'Kimble Applications',
#   'http://www.kimbleapps.com',
#   'Software developer',
#   'Central London',
#   'Dec-16',
#   '50.60%',
#   '5206',
#   '41',
#   'Set up by serial entrepreneurs with backing from 30 angel investors'],
#  ['81',
#   'Infectious Media',
#   'http://www.infectiousmedia.com',
#   'Advertising software developer',
#   'Central London',
#   'Mar-17',
#   '50.53%',
#   '45177',
#   '101',
#   'Helps customers including Adidas and Expedia convert ad views to sales'],
#  ['82',
#   'NewVoiceMedia',
#   'http://www.newvoicemedia.com',
#   'Contact centre software developer',
#   'Basingstoke',
#   'Jan-17',
#   '50.18%',
#   '32204',
#   '370',
#   'Has raised more than £100m from investors including BGF Ventures'],
#  ['83',
#   'ActiveQuote',
#   'http://www.activequote.com',
#   'Price comparison website',
#   'Cardiff',
#   'Sep-16',
#   '49.02%',
#   '7598',
#   '129',
#   'Its technology is used by other websites such as Gocompare and uSwitch'],
#  ['84',
#   'Brandwatch',
#   'http://www.brandwatch.com',
#   'Social media monitoring',
#   'Brighton',
#   'Dec-16',
#   '48.96%',
#   '29100',
#   '354',
#   'Says it collects 200m online data points every day'],
#  ['85',
#   'Lyst',
#   'http://www.lyst.com',
#   'Fashion search platform',
#   'East London',
#   'Mar-17',
#   '48.66%',
#   '10538',
#   '120',
#   'Has raised £39m from technology investors including Accel Partners and Balderton'],
#  ['86',
#   'Godel Technologies',
#   'http://www.godeltech.com',
#   'Software developer',
#   'Manchester',
#   'Dec-16',
#   '48.65%',
#   '9052',
#   '350',
#   'Is named after the late German mathematician Kurt Gödel'],
#  ['87',
#   'PrivateFly',
#   'http://www.privatefly.com',
#   'Online private jet hire',
#   'St Albans',
#   'May-17',
#   '48.38%',
#   '22259',
#   '31',
#   'Opened an office in Fort Lauderdale last year to serve the growing American market'],
#  ['88',
#   'Spektrix',
#   'http://www.spektrix.com',
#   'Ticketing software supplier',
#   'Central London',
#   'Dec-16',
#   '48.04%',
#   '5152',
#   '65',
#   'Processed sales of more than 15m theatre tickets in 2016'],
#  ['89',
#   'Chameleon',
#   'http://www.chameleontechnology.co.uk',
#   'Smart energy monitoring',
#   'Harrogate',
#   'Dec-16',
#   '47.97%',
#   '10860',
#   '21',
#   'Almost 2m of its energy display units have been installed in UK homes'],
#  ['90',
#   'Bullitt Group',
#   'http://www.bullitt-group.com',
#   'Consumer electronics designer',
#   'Reading',
#   'Dec-16',
#   '46.86%',
#   '99673',
#   '98',
#   'Sells its branded electronics to more than 70 countries'],
#  ['91',
#   'Lineup Systems',
#   'http://www.lineup.com',
#   'Advertising technology developer',
#   'Central London',
#   'Jun-16',
#   '46.16%',
#   '7285',
#   '85',
#   'Its software comes in 21 languages and has 8,000 users across 33 countries'],
#  ['92',
#   'Ratio',
#   'http://www.ratio.co.uk',
#   'Price comparison website',
#   'Bournemouth',
#   'Apr-17',
#   '46.11%',
#   '8756',
#   '22',
#   'Its diverse services range from a price comparison site to an underwear subscription club'],
#  ['93',
#   'SaleCycle',
#   'http://www.salecycle.com',
#   'Marketing technology developer',
#   'Tyne and Wear',
#   'Mar-17',
#   '45.85%',
#   '12034',
#   '154',
#   'It has helped companies such as Virgin Atlantic increase online sales by more than 5%'],
#  ['94',
#   'Feefo',
#   'http://www.feefo.com',
#   'Customer review platform',
#   'Hampshire',
#   'Mar-17',
#   '45.07%',
#   '8090',
#   '100',
#   'More than 3,500 brands use Feefo to collect reliable customer feedback'],
#  ['95',
#   'Dianomi',
#   'http://www.dianomi.com',
#   'Content marketing services',
#   'Central London',
#   'Dec-16',
#   '44.24%',
#   '8702',
#   '22',
#   'Its technology places more than 3.5bn ads each month on financial news websites'],
#  ['96',
#   'MVF',
#   'http://www.mvfglobal.com',
#   'Digital marketing agency',
#   'North London',
#   'Mar-17',
#   '44.06%',
#   '54257',
#   '319',
#   'In February it acquired publisher Startups.co.uk for an undisclosed sum'],
#  ['97',
#   'Know Your Money',
#   'http://www.knowyourmoney.co.uk',
#   'Price comparison website',
#   'Norwich',
#   'Mar-17',
#   '43.94%',
#   '8369',
#   '17',
#   'Its three co-founders launched the business in 2004 with a £5,000 credit-card loan'],
#  ['98',
#   'Edge Testing Solutions',
#   'http://www.edgetesting.co.uk',
#   'Software testing provider',
#   'Glasgow',
#   'Dec-16',
#   '42.46%',
#   '10099',
#   '91',
#   'Offers two hubs for its clients to test their products before launch'],
#  ['99',
#   'M24Seven',
#   'http://www.m247.com',
#   'Internet services provider',
#   'Manchester',
#   'Mar-17',
#   '42.43%',
#   '33555',
#   '217',
#   'Acquired internet infrastructure and hosting firm M247 for £47.5m last October'],
#  ['100',
#   'CV-Library Holdings',
#   'http://www.cv-library.co.uk',
#   'Online job site',
#   'Hampshire',
#   'Jun-16',
#   '42.03%',
#   '25186',
#   '132',
#   'Stores nearly 12m CVs on its website']]
